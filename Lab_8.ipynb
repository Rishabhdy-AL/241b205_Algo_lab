# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishabhdy-AL/241b205_Algo_lab/blob/main/Lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minimum Cost Spanning Tree
# Problem Description:
# A spanning tree of a graph can be defined as a graph with minimal set of edges that connect all vertices. A minimum spanning tree of a graph is a spanning tree of the graph with least weight (where the weight is computed by adding the weights of all the edges in the spanning tree). In general, a graph can have multiple minimum spanning trees. The problem is to find a minimum spanning tree of a graph.

# %% [markdown]
# This implementation uses a dictionary to represent the weighted graph, where the vertices are keys, and the values are dictionaries containing their adjacent vertices and their weights.
#
# Please note that this implementation assumes that the input graph is connected and weighted.
#
# First, let's create a simple graph to demonstrate Prim's algorithm:

# %%
graph = {
    "A": {"B": 10, "C": 15, "D": 20},
    "B": {"A": 10, "C": 12},
    "C": {"A": 15, "B": 12, "D": 18},
    "D": {"A": 20, "C": 18},
}

# %% [markdown]
# Now, let's implement Prim's algorithm:

# %%
def prim_algorithm(graph):
    min_tree = {}
    visited = set()
    min_tree[list(graph.keys())[0]] = []
    min_weight = 0

    while len(visited) < len(graph):
        min_edge = float('inf')
        next_vertex = None
        for vertex in min_tree:
            for adj_vertex, weight in graph[vertex].items():
                if adj_vertex not in visited:
                    if weight < min_edge:
                        min_edge = weight
                        next_vertex = adj_vertex

        min_tree[next_vertex] = []
        visited.add(next_vertex)
        min_weight += min_edge

    return min_tree, min_weight

# %% [markdown]
# Now, let's run the Prim's algorithm on the example graph:
# Keep in mind that this example uses a simple representation of a graph, but for more complex cases, you might want to use a library such as NetworkX to represent and manipulate graphs.

# %%
mst, min_weight = prim_algorithm(graph)
print("Minimum Spanning Tree: ", mst)
print("Minimum Weight: ", min_weight)
# Out:
# Minimum Spanning Tree:  {'A': [], 'B': [], 'C': [], 'D': []}
# Minimum Weight:  50

# %% [markdown]
# Take Differnt example of input graph as discussed in lecture slide and use above code to verify the output

# %%
graph2 = {
    "A": {"B": 4, "H": 8},
    "B": {"A": 4, "C": 8, "H": 11},
    "C": {"B": 8, "D": 7, "F": 4, "I": 2},
    "D": {"C": 7, "E": 9, "F": 14},
    "E": {"D": 9, "F": 10},
    "F": {"C": 4, "D": 14, "E": 10, "G": 2},
    "G": {"F": 2, "H": 1, "I": 6},
    "H": {"A": 8, "B": 11, "G": 1, "I": 7},
    "I": {"C": 2, "G": 6, "H": 7}
}

# %%
mst2, min_weight2 = prim_algorithm(graph2)
print("Minimum Spanning Tree for graph2: ", mst2)
print("Minimum Weight for graph2: ", min_weight2)
# Out:
# Minimum Spanning Tree for graph2:  {'A': [], 'B': [], 'H': [], 'G': [], 'F': [], 'C': [], 'I': [], 'D': [], 'E': []}
# Minimum Weight for graph2:  41

# %% [markdown]
# Use same apporach for Kruskal's algorithm

# %%
# implement Kruskal's algorithm

# %%
def find(parent, i):
    if parent[i] == i:
        return i
    parent[i] = find(parent, parent[i])
    return parent[i]

def union(parent, rank, i, j):
    root_i = find(parent, i)
    root_j = find(parent, j)
    if root_i != root_j:
        if rank[root_i] < rank[root_j]:
            parent[root_i] = root_j
        elif rank[root_i] > rank[root_j]:
            parent[root_j] = root_i
        else:
            parent[root_j] = root_i
            rank[root_i] += 1
        return True
    return False

def kruskal_algorithm(graph):
    edges = []
    for u in graph:
        for v, weight in graph[u].items():
            edges.append((weight, u, v))
    edges.sort() # Sort edges by weight

    num_vertices = len(graph)
    vertices = list(graph.keys())
    parent = {v: v for v in vertices}
    rank = {v: 0 for v in vertices}

    mst_edges = []
    min_weight = 0
    num_edges = 0

    for weight, u, v in edges:
        if num_edges == num_vertices - 1:
            break

        if union(parent, rank, u, v):
            mst_edges.append((u, v, weight))
            min_weight += weight
            num_edges += 1

    # Convert mst_edges to a dictionary similar to Prim's output for consistency
    mst_dict = {v: [] for v in vertices}
    for u, v, _ in mst_edges:
        mst_dict[u].append(v) # Note: This doesn't store weights or mirror edges
        mst_dict[v].append(u)

    return mst_dict, min_weight

# %% [markdown]
# Now, let's run Kruskal's algorithm on `graph` and `graph2`:

# %%
mst_kruskal1, min_weight_kruskal1 = kruskal_algorithm(graph)
print("Minimum Spanning Tree (Kruskal) for graph: ", mst_kruskal1)
print("Minimum Weight (Kruskal) for graph: ", min_weight_kruskal1)

mst_kruskal2, min_weight_kruskal2 = kruskal_algorithm(graph2)
print("Minimum Spanning Tree (Kruskal) for graph2: ", mst_kruskal2)
print("Minimum Weight (Kruskal) for graph2: ", min_weight_kruskal2)
# Out:
# Minimum Spanning Tree (Kruskal) for graph:  {'A': ['B'], 'B': ['A', 'C'], 'C': ['B', 'D'], 'D': ['C']}
# Minimum Weight (Kruskal) for graph:  40
# Minimum Spanning Tree (Kruskal) for graph2:  {'A': ['B', 'H'], 'B': ['A'], 'C': ['I', 'F', 'D'], 'D': ['C', 'E'], 'E': ['D'], 'F': ['G', 'C'], 'G': ['H', 'F'], 'H': ['G', 'A'], 'I': ['C']}
# Minimum Weight (Kruskal) for graph2:  37
